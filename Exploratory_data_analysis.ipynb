# %% [markdown]
# <a href="https://colab.research.google.com/github/arshiyafathima1/Data-Preprocessing-/blob/main/Exploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Titanic-Dataset.csv')

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.shape
# Out:
# (891, 12)

# %%
data.ndim
# Out:
# 2

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(len(data.Embarked.unique()))
print(data.Embarked.unique())
# Out:
# 4
# ['S' 'C' 'Q' nan]

# %%
print(len(data.Sex.unique()))
print(data.Sex.unique())
# Out:
# 2
# ['male' 'female']

# %%
print(len(data.Pclass.unique()))
print(data.Pclass.unique())
# Out:
# 3
# [3 1 2]

# %%
print(len(data.Parch.unique()))
print(data.Parch.unique())
# Out:
# 7
# [0 1 2 5 3 4 6]

# %%
#distribution plot for parameters
sns.distplot(data['Survived'],bins=30)
# Out:
# /tmp/ipython-input-3106722621.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Survived'],bins=30)
# <Axes: xlabel='Survived', ylabel='Density'>

# %%
sns.distplot(data['Age'],bins=10)
# Out:
# /tmp/ipython-input-3231215154.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'],bins=10)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(data['Fare'],bins=10)
# Out:
# /tmp/ipython-input-659798996.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Fare'],bins=10)
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.distplot(data['Parch'],bins=25)
# Out:
# /tmp/ipython-input-913870180.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Parch'],bins=25)
# <Axes: xlabel='Parch', ylabel='Density'>

# %%
sns.distplot(data['SibSp'],bins=25)
# Out:
# /tmp/ipython-input-3458094980.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['SibSp'],bins=25)
# <Axes: xlabel='SibSp', ylabel='Density'>

# %%
sns.distplot(data['Pclass'],bins=5)
# Out:
# /tmp/ipython-input-3885534715.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Pclass'],bins=5)
# <Axes: xlabel='Pclass', ylabel='Density'>

# %%
#distribution plot for parameters
sns.distplot(data['Survived'],bins=30)
# Out:
# /tmp/ipython-input-3106722621.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Survived'],bins=30)
# <Axes: xlabel='Survived', ylabel='Density'>

# %%
sns.distplot(data['Age'],bins=10)
# Out:
# /tmp/ipython-input-3231215154.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'],bins=10)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(data['Fare'],bins=10)
# Out:
# /tmp/ipython-input-659798996.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Fare'],bins=10)
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.distplot(data['SibSp'],bins=25)
# Out:
# /tmp/ipython-input-3458094980.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['SibSp'],bins=25)
# <Axes: xlabel='SibSp', ylabel='Density'>

# %%
sns.distplot(data['Pclass'],bins=25)
# Out:
# /tmp/ipython-input-3381400191.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Pclass'],bins=25)
# <Axes: xlabel='Pclass', ylabel='Density'>

# %%
sns.distplot(data['Parch'],bins=25)
# Out:
# /tmp/ipython-input-913870180.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Parch'],bins=25)
# <Axes: xlabel='Parch', ylabel='Density'>

# %%
#OUTLIER ANALYSIS WITH BOXPLOT
sns.boxplot(data['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
data_early_age = data.loc[data['Age']<15]
data_early_age
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 827          828         1       2                    Mallet, Master. Andre
# 831          832         1       2          Richards, Master. George Sibley
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 869          870         1       3          Johnson, Master. Harold Theodor
#
# ...

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='Sex',y='Age',hue='Survived',data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='Age',y='Fare',hue='Survived',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.histplot(x='Age',hue='Survived',data=data_early_age)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#HANDLING THE OUTLIERS
Q1 = data['Age'].quantile(0.25)
Q3 = data['Age'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 17.875

# %%
data = data[~((data['Age'] < (Q1 - 1.5 * IQR)) |(data['Age'] > (Q3 + 1.5 * IQR)))]

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# DATA IMPUTATION
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         2
# dtype: int64

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         2
# dtype: int64

# %%
# DATA IMPUTATION
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         2
# dtype: int64

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         2
# dtype: int64

# %%
#relationship between columns
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.scatterplot(x='Age',y='Fare',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='Age',y='Embarked',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Embarked'>

# %%
data.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 42.  , 21.  , 18.  ,  3.  ,  7.  , 49.  ,
#        29.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  , 16.  , 25.  ,
#         0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  , 37.  , 47.  ,
#        14.5 , 32.5 , 12.  ,  9.  , 36.5 , 51.  , 55.5 , 40.5 , 44.  ,
#         1.  , 61.  , 56.  , 50.  , 36.  , 45.5 , 20.5 , 62.  , 41.  ,
#        52.  , 63.  , 23.5 ,  0.92, 43.  , 60.  , 10.  , 64.  , 13.  ,
#        48.  ,  0.75, 53.  , 57.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42,
#        34.5 ])

# %%
# Calculate correlation only for numerical columns
correlation = data.select_dtypes(include=np.number).corr()
display(correlation)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.008400 -0.037129  0.044883 -0.060252 -0.002156
# Survived       -0.008400  1.000000 -0.346577 -0.055246 -0.038307  0.080786
# Pclass         -0.037129 -0.346577  1.000000 -0.369442  0.081455  0.018927
# Age             0.044883 -0.055246 -0.369442  1.000000 -0.308555 -0.188068
# SibSp          -0.060252 -0.038307  0.081455 -0.308555  1.000000  0.413904
# Parch          -0.002156  0.080786  0.018927 -0.188068  0.413904  1.000000
# Fare            0.012269  0.258221 -0.551653  0.107703  0.158880  0.214564
#
#                  Fare
# PassengerId  0.012269
# Survived     0.258221
# Pclass      -0.551653
# Age          0.107703
# SibSp        0.158880
# Parch        0.214564
# Fare         1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >
